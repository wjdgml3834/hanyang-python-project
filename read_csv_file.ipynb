# %%
import pandas as pd

# data 불러오기 (판다스 기능 이용)
data = pd.read_csv('./data/leisure_data.csv')

print(data)
# 데이터 프레임 내의 처음 n줄의 데이터를 출력합니다.
# n의 기본 값은 5이며 아무 입력이 없을 경우 5줄을 기본으로 출력합니다.
# print(data.head())

# 데이터셋 크기 (행,열) 확인
# print(data.shape)

# 세개의 행만 볼 수 있게 합니다.
# print(data.head(3))

# value 정보만 보기.
# print(data.values)

# 정보 보기
# print(data.info())

# 열만 보기
# print(data[['2021.2']])

# 요약 통계량 확인 
# print(data.describe())
# Out:
#     구분별(1)  구분별(2)        구분별(3)     2021 2021.1  2021.2 2021.3 2021.4 2021.5  \
# 0   구분별(1)  구분별(2)        구분별(3)  여행야외나들이   영상시청  문화예술관람     운동     휴식   종교활동
# 1      서울시      소계            소계     13.7   28.7    12.3   12.4   10.4    1.1
# 2      서울시      성별            남자     12.8   27.6    10.4   13.8   10.3    0.6
# 3      서울시      성별            여자     14.5   29.7    14.0   11.1   10.6    1.6
# 4      서울시     연령별           10대     10.5   24.8     8.1   10.9    9.4    0.5
# 5      서울시     연령별           20대     10.7   19.6    15.1   12.3    9.8    0.3
# 6      서울시     연령별           30대     13.2   23.4    13.4   12.6   12.2    0.6
# 7      서울시     연령별           40대     14.3   25.3    13.0   13.9   12.4    0.9
# 8      서울시     연령별           50대     15.9   29.3    13.1   11.9    9.9    1.4
# 9      서울시     연령별        60대 이상     14.6   40.7     9.4   11.9    8.9    2.1
# 10     서울시     학력별         중졸 이하     12.9   43.8     7.5   10.6   11.3    2.1
# ...
